# %% [markdown]
# 3 Import the required packages with their customary aliases as follows:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# 4 Use the %matplotlib inline magic command so that your plots show in the notebook without having to   call plt.show() every time.

# %% [markdown]
# 5 Using the pandas read_csv() method, read the GDP dataset into your notebook as a DataFrame
#   called gdp_df. Take a look at the first 6 rows.

# %%
gdp_df = pd.read_csv('data\gdp_percapita.csv',nrows=6606)
#gdp_df = pd.read_csv('..\gdp_percapita.csv') ..if it was in the one folder above

# %%
gdp_df.head()
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2018  2190.240321              NaN
# 1     Afghanistan  2017  2202.570851              NaN
# 2     Afghanistan  2016  2200.764487              NaN
# 3     Afghanistan  2015  2212.750899              NaN
# 4     Afghanistan  2014  2249.253738              NaN

# %% [markdown]
# 6 Repeat for the internet use dataset. Call this DataFrame internet_df. Take a look at the first six rows.

# %%
internet_df = pd.read_csv('data\internet_use.csv',nrows=4495)

# %%
internet_df.head(6)
# Out:
#   Country or Area  Year     Value  Value Footnotes  Unnamed: 4  Unnamed: 5
# 0     Afghanistan  2014  6.390000              NaN         NaN         NaN
# 1     Afghanistan  2013  5.900000              NaN         NaN         NaN
# 2     Afghanistan  2012  5.454545              NaN         NaN         NaN
# 3     Afghanistan  2011  5.000000              NaN         NaN         NaN
# 4     Afghanistan  2010  4.000000              NaN         NaN         NaN
# 5     Afghanistan  2009  3.550000              NaN         NaN         NaN

# %% [markdown]
# 7 Look at the shape of each DataFrame - how many rows? How many columns?

# %%
len(gdp_df)    #number of rows in gdp
# Out:
# 6606

# %%
len(internet_df)   #number of rows in iu with out the footnotes
# Out:
# 4495

# %%
len(gdp_df.columns)
len(internet_df.columns)
# Out:
# 6

# %%
dataTypeSeries = gdp_df.dtypes
print('Data type of each column of gdp_df :')
print(dataTypeSeries)
# Out:
# Data type of each column of gdp_df :
# Country or Area     object
# Year                 int64
# Value              float64
# Value Footnotes    float64
# dtype: object

# %% [markdown]
# #8 Take a look at the datatypes for the columns in each DataFrame.

# %%
gdp_df.info()
internet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6606 entries, 0 to 6605
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country or Area  6606 non-null   object
#  1   Year             6606 non-null   int64
#  2   Value            6606 non-null   float64
#  3   Value Footnotes  1 non-null      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 206.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4495 entries, 0 to 4494
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country or Area  4495 non-null   object
#  1   Year             4495 non-null   int64
#  2   Value            4495 non-null   float64
#  3   Value Footnotes  948 non-null    float64
#  4   Unnamed: 4       0 non-null      float64
#  5   Unnamed: 5       0 non-null      float64
# dtypes: float64(4), int64(1), object(1)
# ...

# %% [markdown]
# #9 Take a look at the last 10 rows of each DataFrame in turn.

# %%
gdp_df.tail(10)
#internet_df.tail(10)
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 6596        Zimbabwe  1999  3600.849291              NaN
# 6597        Zimbabwe  1998  3653.920016              NaN
# 6598        Zimbabwe  1997  3580.048793              NaN
# 6599        Zimbabwe  1996  3520.430146              NaN
# 6600        Zimbabwe  1995  3226.413930              NaN
# 6601        Zimbabwe  1994  3263.934978              NaN
# 6602        Zimbabwe  1993  3033.504852              NaN
# 6603        Zimbabwe  1992  3054.889178              NaN
# 6604        Zimbabwe  1991  3426.598094              NaN
# 6605        Zimbabwe  1990  3324.348171              NaN

# %% [markdown]
# 10  Drop the value footnotes column from both  DataFrames.Check that this worked as expected.

# %%
internet_df.drop(columns=['Value Footnotes','Unnamed: 4','Unnamed: 5'],inplace=True)
internet_df.head()
# Out:
#   Country or Area  Year     Value
# 0     Afghanistan  2014  6.390000
# 1     Afghanistan  2013  5.900000
# 2     Afghanistan  2012  5.454545
# 3     Afghanistan  2011  5.000000
# 4     Afghanistan  2010  4.000000

# %%
gdp_df.drop(columns=['Value Footnotes'],inplace=True)
gdp_df.head()
# Out:
#   Country or Area  Year        Value
# 0     Afghanistan  2018  2190.240321
# 1     Afghanistan  2017  2202.570851
# 2     Afghanistan  2016  2200.764487
# 3     Afghanistan  2015  2212.750899
# 4     Afghanistan  2014  2249.253738

# %% [markdown]
# 11 Change the columns for the GDP Per Capita DataFrame to ‘Country’, ‘Year’, and ‘GDP_Per_Capita’.

# %%
new_col_names_gdp = ['Country','Year','GDP_Per_Capita']
gdp_df.columns = new_col_names_gdp
gdp_df.head()
# Out:
#        Country  Year  GDP_Per_Capita
# 0  Afghanistan  2018     2190.240321
# 1  Afghanistan  2017     2202.570851
# 2  Afghanistan  2016     2200.764487
# 3  Afghanistan  2015     2212.750899
# 4  Afghanistan  2014     2249.253738

# %% [markdown]
# 12 Change the columns for the Internet Users DataFrame to ‘Country’, ‘Year’, and
#    ‘Internet_Users_Pct’.

# %%
new_col_names_int = ['Country','Year','Internet_Users_Pct']
internet_df.columns = new_col_names_int
internet_df.head()
# Out:
#        Country  Year  Internet_Users_Pct
# 0  Afghanistan  2014            6.390000
# 1  Afghanistan  2013            5.900000
# 2  Afghanistan  2012            5.454545
# 3  Afghanistan  2011            5.000000
# 4  Afghanistan  2010            4.000000

# %% [markdown]
# 13 Merge the two DataFrames to one. Merge all rows from each of the two DataFrames. Call the new DataFrame gdp_and_internet_use.

# %%
gdp_df['Year'].astype('int')
gdp_and_internet_use = pd.merge(gdp_df, internet_df, how='outer')
gdp_and_internet_use.head()
# Out:
#        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0  Afghanistan  2018     2190.240321                 NaN
# 1  Afghanistan  2017     2202.570851                 NaN
# 2  Afghanistan  2016     2200.764487                 NaN
# 3  Afghanistan  2015     2212.750899                 NaN
# 4  Afghanistan  2014     2249.253738                6.39

# %%
gdp_and_internet_use.shape
# Out:
# (7664, 4)

# %%
14. Look at the first five rows of your new DataFrame to confirm it merged correctly.
# Out:
#   File "<ipython-input-191-5ebb05dcaf68>", line 1
#     14. Look at the first five rows of your new DataFrame to confirm it merged correctly.
#         ^
# SyntaxError: invalid syntax

# %%
gdp_and_internet_use.head()

# %%
15. Look at the last five rows to make sure the data is clean and as expected.

# %%
gdp_and_internet_use.tail()

# %%
16. Subset the combined DataFrame to keep only the data for 2004, 2009, and 2014. Check that this happened correctly.

# %%
"""
from stack oveflow
row_list = ['row_name1', 'row_name2', row_name3']
sliced_rows = df[df['row_names'].isin(row_list)]

"""

# %%
yearsub = [2004,2009,2014]
gdp_and_int_sub = gdp_and_internet_use[gdp_and_internet_use.Year.isin(yearsub)]
gdp_and_int_sub.head()

# %% [markdown]
# 17.Create three new DataFrames, one for 2004, one for 2009, and one for 2014. Give them meaningful names that aren't too long.

# %%
gdp_and_int2004 = gdp_and_internet_use[gdp_and_internet_use.Year == 2004]
gdp_and_int2009 = gdp_and_internet_use[gdp_and_internet_use.Year == 2009]
gdp_and_int2014 = gdp_and_internet_use[gdp_and_internet_use.Year == 2014]

# %%
#gdp_and_int2004.head()
#gdp_and_int2009.head()
gdp_and_int2014.head()

# %% [markdown]
# 18.Which country had the highest percentage of internet users in 2014? What was the percentage? (Try typing the first 3 letters  of your DataFrame name and hitting the tab key for auto-complete options).

# %%
gdp_and_int2014_max_intusers = gdp_and_int2014[gdp_and_int2014['Internet_Users_Pct']==gdp_and_int2014['Internet_Users_Pct'].max()]
print(gdp_and_int2014_max_intusers)

# %% [markdown]
# 19.Which country had the highest percentage of internet users in 2014? What was the percentage? (Try typing the first 3 letters of your DataFrame name and hitting the tab key for auto-complete options).

# %%
gdp_and_int2014_min_intusers = gdp_and_int2014[gdp_and_int2014['Internet_Users_Pct']==gdp_and_int2014['Internet_Users_Pct'].min()]
print(gdp_and_int2014_min_intusers)

# %%
20 .Repeat for 2004 and 2009.

# %%
gdp_and_int2004_max_intusers = gdp_and_int2004[gdp_and_int2004['Internet_Users_Pct']==gdp_and_int2004['Internet_Users_Pct'].max()]
print(gdp_and_int2004_max_intusers)

gdp_and_int2004_min_intusers = gdp_and_int2004[gdp_and_int2004['Internet_Users_Pct']==gdp_and_int2004['Internet_Users_Pct'].min()]
print(gdp_and_int2004_min_intusers)

# %%
gdp_and_int2009_max_intusers = gdp_and_int2009[gdp_and_int2009['Internet_Users_Pct']==gdp_and_int2009['Internet_Users_Pct'].max()]
print(gdp_and_int2009_max_intusers)

gdp_and_int2009_min_intusers = gdp_and_int2009[gdp_and_int2009['Internet_Users_Pct']==gdp_and_int2009['Internet_Users_Pct'].min()]
print(gdp_and_int2009_min_intusers)

# %% [markdown]
# 21.Which country had the highest gdp per capita in 2014? What was the gdp per capita?

# %%
gdp_per_capita_2014_max = gdp_and_int2014[gdp_and_int2014['GDP_Per_Capita']==gdp_and_int2014['GDP_Per_Capita'].max()]
print(gdp_per_capita_2014_max)
# Out:
#                Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 3564  Macao SAR, China  2014     156514.1338                 NaN

# %% [markdown]
# 22. Which country had the lowest gdp per capita in 2014? What was the gdp per capita?

# %%
gdp_per_capita_2014_min = gdp_and_int2014[gdp_and_int2014['GDP_Per_Capita']==gdp_and_int2014['GDP_Per_Capita'].min()]
print(gdp_per_capita_2014_min)

# %% [markdown]
# 23. Create some scatterplots:
# a. 2004 Percent Using the Internet vs GDP Per Capita
# b. 2009 Percent Using the Internet vs GDP Per Capita
# c. 2014 Percent Using the Internet vs GDP Per Capita

# %% [markdown]
# a. 2004 Percent Using the Internet vs GDP Per Capita

# %%
plt.scatter(gdp_and_int2004.Internet_Users_Pct, gdp_and_int2004.GDP_Per_Capita)
plt.xlabel('Percent of Internet Users')
plt.ylabel('GDP Per Capita')
plt.title('2004 Internet Usage vs GDP Per Capita')
plt.show()

# %%
2009 Percent Using the Internet vs GDP Per Capita

# %%
plt.scatter(gdp_and_int2009.Internet_Users_Pct, gdp_and_int2009.GDP_Per_Capita)
plt.xlabel('Percent of Internet Users')
plt.ylabel('GDP Per Capita')
plt.title('2009 Internet Usage vs GDP Per Capita')
plt.show()

# %% [markdown]
# 2014 Percent Using the Internet vs GDP Per Capita

# %%
plt.scatter(gdp_and_int2014.GDP_Per_Capita, gdp_and_int2014.Internet_Users_Pct)
plt.xlabel('Percent of Internet Users')
plt.ylabel('GDP Per Capita')
plt.title('2014 Internet Usage vs GDP Per Capita')
plt.show()

# %% [markdown]
# 24. Are there differences across years? What do the plots tell you about any relationship between these two variables?
#     Enter your observations as a markdown cell.

# %%
looks the two variable directly proportional across the year , when GDP per Capita increased the # of internet users seams increasing .

# %%
25. Look at the distribution of gdp per capita values for 2014. Is it unimodal?

# %%
plt.hist(gdp_and_int2014.GDP_Per_Capita)
plt.xlabel('GDP Per Capita')
plt.ylabel('Frequency')
plt.show()

# %%
It looks unimodal !!

# %% [markdown]
# 26. Look at the distribution of Internet Use for 2014. Is it unimodal?

# %%
plt.hist(gdp_and_int2014.Internet_Users_Pct)
plt.xlabel('Percentage of Internet Users')
plt.ylabel('Frequency')
plt.show()

# %%
It Looks multimodal !!

# %%
27. What are the top 5 countries in terms of internet use in 2014?

# %%
Sorted2014 = gdp_and_int2014.sort_values('Internet_Users_Pct', ascending = False)
Sorted2014.head(5)
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2507  Iceland  2014     49911.06982               98.16
# 6649  Bermuda  2014             NaN               96.80
# 4461   Norway  2014     61308.76373               96.30
# 1374  Denmark  2014     52172.60643               95.99
# 6609  Andorra  2014             NaN               95.90

# %% [markdown]
# 28. Create a DataFrame called top_5_internet from the combined DataFrame that has all three years for
#     the 5 countries that had the greatest 2014 internet usage.You should have 15 rows. Check that
#     this is true.

# %%
h_int_Country = Sorted2014['Country'].head()
top_5_internet = gdp_and_int_sub[gdp_and_int_sub["Country"].isin(h_int_Country)]
print(top_5_internet)
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 1374  Denmark  2014     52172.60643           95.990000
# 1379  Denmark  2009     50233.70269           86.840000
# 1384  Denmark  2004     50566.98809           80.930000
# 2507  Iceland  2014     49911.06982           98.160000
# 2512  Iceland  2009     48428.31244           93.000000
# 2517  Iceland  2004     45380.96546           83.880000
# 4461   Norway  2014     61308.76373           96.300000
# 4466   Norway  2009     60620.33450           92.080000
# 4471   Norway  2004     59647.50141           77.690000
# 6609  Andorra  2014             NaN           95.900000
# 6614  Andorra  2009             NaN           78.530000
# 6619  Andorra  2004             NaN           26.837954
# 6649  Bermuda  2014             NaN           96.800000
# 6654  Bermuda  2009             NaN           83.250000
# 6659  Bermuda  2004             NaN           60.990867

# %% [markdown]
# 29.Create a seaborn FacetGrid to show the internet usage trend across the years 2004, 2009, and 2014 for these 5 countries
#    (those with the highest reported internet use in 2014). Which country had the greatest growth between 2004 and 2014?
#     Is there a plotting issue with Bermuda? Can you fix it?

# %%
internet_use = sns.FacetGrid(tip, col='year')

# %%
g = sns.FacetGrid('Internet_Users_Pct' , col='yeare', height=5)
g.map(plt.plot, "h_int_Country", "Internet_Users_Pct")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-204-499b6d77a825> in <module>
# ----> 1 g = sns.FacetGrid('Internet_Users_Pct' , col='yeare', height=5)
#       2 g.map(plt.plot, "h_int_Country", "Internet_Users_Pct")
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in __init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws, size)
#     334             col_names = []
#     335         else:
# ...

# %%
gdp_2014=is_2014.sort_values(by="GDP_Per_Capita", ascending=False).head(5)
h_country =gdp_2014['Country']
top_5_gdp = filtered_years[filtered_years.Country.isin(h_country)]
#print(top_5_gdp)
#g=sns.FacetGrid(top_5_gdp, col='Country',height=3)
#g.map(plt.plot,"Year","GDP_Per_Capita")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-194-66e36f1ab961> in <module>
# ----> 1 gdp_2014=is_2014.sort_values(by="GDP_Per_Capita", ascending=False).head(5)
#       2 h_country =gdp_2014['Country']
#       3 top_5_gdp = filtered_years[filtered_years.Country.isin(h_country)]
#       4 #print(top_5_gdp)
#       5 #g=sns.FacetGrid(top_5_gdp, col='Country',height=3)
#
# NameError: name 'is_2014' is not defined

# %%
print(top_5_internet)
# Out:
#                                                 Country  Year  GDP_Per_Capita  \
# 0                                           Afghanistan  2018     2190.240321
# 1                                           Afghanistan  2017     2202.570851
# 2                                           Afghanistan  2016     2200.764487
# 3                                           Afghanistan  2015     2212.750899
# 4                                           Afghanistan  2014     2249.253738
# 5                                           Afghanistan  2013     2264.317575
# 6                                           Afghanistan  2012     2220.481526
# 7                                           Afghanistan  2011     2037.608607
# 8                                           Afghanistan  2010     2093.743565
# 9                                           Afghanistan  2009     1881.777626
# 10                                          Afghanistan  2008     1587.792070
# ...

# %%
sliced_rows = df[df['row_names'].isin(row_list)]

# %%
"""
This is a "block comment" in Python, made
out of a mult-line string constant.
This actually works quite well!
"""
print(42)
# Out:
# 42

# %%
'''
This is a "block comment" in Python, made
out of a mult-line string constant.
This actually works quite well!
'''
print(42)
# Out:
# 42
